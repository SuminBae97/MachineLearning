# %% [markdown]
# - Kaggle Competition

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("weatherAUS.csv")

# %%
df.shape
# Out:
# (145460, 23)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.head(10)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# 5  2008-12-06   Albury     14.6     29.7       0.2          NaN       NaN
# 6  2008-12-07   Albury     14.3     25.0       0.0          NaN       NaN
# 7  2008-12-08   Albury      7.7     26.7       0.0          NaN       NaN
# 8  2008-12-09   Albury      9.7     31.9       0.0          NaN       NaN
# 9  2008-12-10   Albury     13.1     30.1       1.4          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# ...

# %%
df['Location'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Albury
# 1         Albury
# 2         Albury
# 3         Albury
# 4         Albury
#            ...
# 145455     Uluru
# 145456     Uluru
# 145457     Uluru
# 145458     Uluru
# 145459     Uluru
# Name: Location, Length: 145460, dtype: object>

# %% [markdown]
# - checking the null count for each row

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Sunshine         69835
# Evaporation      62790
# Cloud3pm         59358
# Cloud9am         55888
# Pressure9am      15065
# Pressure3pm      15028
# WindDir9am       10566
# WindGustDir      10326
# WindGustSpeed    10263
# Humidity3pm       4507
# WindDir3pm        4228
# Temp3pm           3609
# RainTomorrow      3267
# RainToday         3261
# Rainfall          3261
# WindSpeed3pm      3062
# Humidity9am       2654
# WindSpeed9am      1767
# Temp9am           1767
# MinTemp           1485
# MaxTemp           1261
# Location             0
# Date                 0
# dtype: int64

# %%
check = df.isnull().sum().sort_values(ascending=False)

# %%
check
# Out:
# Sunshine         69835
# Evaporation      62790
# Cloud3pm         59358
# Cloud9am         55888
# Pressure9am      15065
# Pressure3pm      15028
# WindDir9am       10566
# WindGustDir      10326
# WindGustSpeed    10263
# Humidity3pm       4507
# WindDir3pm        4228
# Temp3pm           3609
# RainTomorrow      3267
# RainToday         3261
# Rainfall          3261
# WindSpeed3pm      3062
# Humidity9am       2654
# WindSpeed9am      1767
# Temp9am           1767
# MinTemp           1485
# MaxTemp           1261
# Location             0
# Date                 0
# dtype: int64

# %%
zero_pct = (df.isnull().sum() / df.isnull().count()).sort_values(ascending=False)

# %%
missing = pd.concat([check,zero_pct],axis=1 , keys = ['amount','pct'])

# %%
missing
# Out:
#                amount       pct
# Sunshine        69835  0.480098
# Evaporation     62790  0.431665
# Cloud3pm        59358  0.408071
# Cloud9am        55888  0.384216
# Pressure9am     15065  0.103568
# Pressure3pm     15028  0.103314
# WindDir9am      10566  0.072639
# WindGustDir     10326  0.070989
# WindGustSpeed   10263  0.070555
# Humidity3pm      4507  0.030984
# WindDir3pm       4228  0.029066
# Temp3pm          3609  0.024811
# RainTomorrow     3267  0.022460
# RainToday        3261  0.022419
# Rainfall         3261  0.022419
# WindSpeed3pm     3062  0.021050
# Humidity9am      2654  0.018246
# WindSpeed9am     1767  0.012148
# Temp9am          1767  0.012148
# MinTemp          1485  0.010209
# MaxTemp          1261  0.008669
# Location            0  0.000000
# Date                0  0.000000

# %% [markdown]
# # delete 'Sunshine' , ' Evaporation , 'Clould3pm' , 'Cloud9am'

# %% [markdown]
# - selected 4 features that has too much missing values

# %%
unece_feat = list(missing[missing['pct']>0.15].index)

# %%
unece_feat
# Out:
# ['Sunshine', 'Evaporation', 'Cloud3pm', 'Cloud9am']
